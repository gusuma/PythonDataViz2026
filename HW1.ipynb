# %% [markdown]
# <a href="https://colab.research.google.com/github/gusuma/PythonDataViz2026/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # กุสุมา บังแสง

# %%
print("ID6630202573")
# Out:
# ID6630202573
